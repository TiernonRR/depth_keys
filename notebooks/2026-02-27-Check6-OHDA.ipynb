# %%
import os 
from glob import glob

# %%
base_dir = "/storage/project/r-jmarkowitz30-0/shared/active_lab_members/markowitz_jeffrey/active_projects/6-OHDA"
sessions = set([item.split("/")[-1] for item in glob(os.path.join(base_dir, "session*"))])

# %%
len(sessions)
# Out:
# 115

# %%
sessions_with_v1 = set([item.split("/")[-4] for item in glob(os.path.join(base_dir, "session*", "_proc", "_kpoints_v1_3d", "merged_keypoints.h5"))])

# %%
len(sessions_with_v1)
# Out:
# 112
