# %%
#TODO update to import pip-installed package

import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), '../experiment'))
sys.path.append(parent_dir)

depth_keys = os.path.abspath(os.path.join(os.getcwd(), '../../'))
sys.path.append(depth_keys)

# %%
from glob import glob

# %%
import trial

# %%
base_dir = "/storage/project/r-jmarkowitz30-0/shared/active_lab_members/markowitz_jeffrey/active_projects"
project = "6-OHDA"
session = 'session_20250613134346-055134 (system76-pc)'

# %%
node_names = [
    "tail_tip",
    "tail_middle",
    "tail_base",
    "back_bottom",
    "back_middle_lower",
    "back_middle_upper",
    "back_top",
    "left_ear",
    "right_ear",
    "snout",
    "left_hip",
    "right_hip",
    "left_shoulder",
    "right_shoulder",
]

# %%
version=1
use_data_dir = os.path.join(base_dir, project, session)
intrinsics_file = "/storage/project/r-jmarkowitz30-0/shared/active_lab_members/markowitz_jeffrey/active_projects/mouse_open_field_lucid_rig_da_photometry/intrinsics_lucid_rig.toml" # these shouldn't change by project
save_dir = os.path.join(base_dir, project, session, "_proc")
inference_output_path = os.path.join(base_dir, project, session, "_proc", f"_keypoints_v{version}")
cable=False

# %%
videos = glob(os.path.join(save_dir, "*.avi"))

# %%
videos
# Out:
# ['/storage/project/r-jmarkowitz30-0/shared/active_lab_members/markowitz_jeffrey/active_projects/6-OHDA/session_20250613134346-055134 (system76-pc)/_proc/Lucid Vision Labs-HTP003S-001-223702048.avi',
#  '/storage/project/r-jmarkowitz30-0/shared/active_lab_members/markowitz_jeffrey/active_projects/6-OHDA/session_20250613134346-055134 (system76-pc)/_proc/Lucid Vision Labs-HTP003S-001-223702266.avi',
#  '/storage/project/r-jmarkowitz30-0/shared/active_lab_members/markowitz_jeffrey/active_projects/6-OHDA/session_20250613134346-055134 (system76-pc)/_proc/Lucid Vision Labs-HTP003S-001-224500508.avi']

# %%
_trial = trial.Trial(trial_id=session, 
                     video_paths=videos, 
                     inference_output_path=inference_output_path,
                     n_body_parts=14)

# %%
_trial.compute_3d_keypoints(use_data_dir, 1, intrinsics_file, 
                                cable, node_names, save_dir)
# Out:
# Using the following avis:
# -> /storage/project/r-jmarkowitz30-0/shared/active_lab_members/markowitz_jeffrey/active_projects/6-OHDA/session_20250613134346-055134 (system76-pc)/_proc/Lucid Vision Labs-HTP003S-001-223702048.avi
# -> /storage/project/r-jmarkowitz30-0/shared/active_lab_members/markowitz_jeffrey/active_projects/6-OHDA/session_20250613134346-055134 (system76-pc)/_proc/Lucid Vision Labs-HTP003S-001-223702266.avi
# -> /storage/project/r-jmarkowitz30-0/shared/active_lab_members/markowitz_jeffrey/active_projects/6-OHDA/session_20250613134346-055134 (system76-pc)/_proc/Lucid Vision Labs-HTP003S-001-224500508.avi
# Converting 2D keypoints to 3D
#   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 _trial.compute_3d_keypoints(use_data_dir, 1, intrinsics_file,
#       2                                 cable, node_names, save_dir)
#
# File /storage/project/r-jmarkowitz30-0/triesenmy3/depth_and_da/depth_keys/experiment/trial.py:105, in Trial.compute_3d_keypoints(self, use_data_dir, version_num, intrinsics_file, cable, node_names, save_dir)
#     101 avis = self.video_paths
#     102 kpoint_root_dir = self.inference_output_path
# --> 105 process_session(use_data_dir,
#     106                 avis,
#     107                 kpoint_root_dir,
#     108                 intrinsics_file,
#     109                 version_num,
#     110                 node_names,
#     111                 cable,
#     112                 save_dir)
#
# File /storage/project/r-jmarkowitz30-0/triesenmy3/depth_and_da/depth_keys/post_processing/post_process.py:38, in process_session(use_data_dir, avis, kpoint_root_dir, intrinsics_file, version_num, node_names, cable, save_dir)
#      32 '''
#      33     Convert 2d to 3d ...
#      34 '''
#      36 print("Converting 2D keypoints to 3D")
# ---> 38 _ = convert_2d_to_3d(intrinsics_file,
#      39                     kpoint_root_dir,
#      40                     avis,
#      41                     version_num,
#      42                     cable,
#      43                     node_names)
#      45 '''
#      46     Merge keypoints across views...
#      47 '''
#      49 print("Merging keypoints...")
#
# File /storage/project/r-jmarkowitz30-0/triesenmy3/depth_and_da/depth_keys/post_processing/conversion_computations.py:209, in convert_2d_to_3d(intrinsics_file, kpoint_root_dir, avis, version_num, cable, node_names)
#     206 if len(_frame.instances) == 0 :
#     207     continue
# --> 209 points = _frame.instances[0]._points # _points returns all points, points only returns labeled points
#     210 for j in range(points.shape[0]):
#     211     _point = points[j]
#
# AttributeError: 'PredictedInstance' object has no attribute '_points'

# %%
slepa = glob(os.path.join(save_dir, "*", "*.slp"))

# %%
import sleap_io as sio
_dat = sio.load_file(slepa[0])

# %%
_dat[0].instances[0].points[0]
# Out:
# np.void(([nan, nan], 0.0, True, False, 'tail_tip'), dtype=[('xy', '<f8', (2,)), ('score', '<f8'), ('visible', '?'), ('complete', '?'), ('name', 'O')])

# %%
# Access the structured array
points = _dat[0].instances[0].points 

for j in range(points.shape[0]):
    _point = points[j]
    
    # Access 'xy' field, index 0 is x, index 1 is y
    new_arr[i][j][0] = _point['xy'][0]  
    new_arr[i][j][1] = _point['xy'][1]
    
    # Access 'score' field
    new_arr[i][j][2] = _point['score']
