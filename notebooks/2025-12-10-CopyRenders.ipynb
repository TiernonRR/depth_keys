# %%
import os
from glob import glob
import shutil

# %%
dst_dir = "./renders"
os.makedirs(dst_dir, exist_ok=True)

# %%
base_dir = "/storage/project/r-jmarkowitz30-0/shared/active_lab_members/markowitz_jeffrey/active_projects"
BiPOLES_dir = os.path.join(base_dir, "mouse_open_field_lucid_rig_da_bipoles")
matplot_renders = glob(os.path.join(BiPOLES_dir, "session*", "_proc", "renders", "matplotlib_render_v1.mp4"))

# %%
for file_path in matplot_renders:

    session = file_path.split("/")[-4]
    
    shutil.copy2(file_path, os.path.join(dst_dir, f"{session}-matplot.mp4"))
